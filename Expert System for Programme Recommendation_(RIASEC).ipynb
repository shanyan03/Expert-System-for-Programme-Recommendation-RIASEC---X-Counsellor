# %%
import random

def take_riasec_test():
    print("Welcome to X-Counsellor \U0001F600, your trusted companion for guidance in choosing your best courses.\u270C")
    print("Our goal is to make your journey of selecting courses a smooth and enjoyable experience!")
    print("To assist you in selecting the best courses for your needs, please take a moment to answer a few simple questions.")
    print("------------------------------------------------------------------------------------------------------------------")
    print("\033[1mATTENTION!!!\033[0m Please answer the questions thoughtfully and honestly to ensure accurate results \033[1m!!!\033[1mATTENTION\033[0m")
    print("------------------------------------------------------------------------------------------------------------------")
    print("Please rate the following statements from 1 (strongly disagree) to 5 (strongly agree).")
    print("------------------------------------------------------------------------------------------------------------------")

    scores = {'R': 0, 'I': 0, 'A': 0, 'S': 0, 'E': 0, 'C': 0}

    questions = [
        "I enjoy working with my hands and being physically active.",
        "I have a strong interest in scientific and mathematical theories.",
        "I enjoy expressing myself through art, music, or writing.",
        "I enjoy helping and teaching others.",
        "I like to lead and influence others.",
        "I prefer following clearly defined procedures and rules.",
        
        "I am interested in solving mechanical problems.",
        "I am curious about how things work and enjoy conducting experiments.",
        "I am interested in exploring my creativity and trying new forms of expression.",
        "I am passionate about social issues and making a positive impact on society.",
        "I am interested in sales, negotiation, and building professional relationships.",
        "I am good at organizing, paying attention to detail, and working with numbers.",
        
        "I enjoy engaging in hands-on activities such as woodworking, crafting, or gardening.",
        "I have a strong curiosity and enjoy exploring new ideas and concepts.",
        "I have a deep passion for creative expression through visual arts, such as painting, drawing, or photography.",
        "I find fulfillment in helping others and making a positive impact in their lives.",
        "I enjoy taking charge and leading others towards a common goal.",
        "I prefer working with structured systems, organizing data, or managing details.",
        
        "I am naturally inclined towards careers that involve physical work and practical problem-solving, such as construction or automotive repair.",
        "I am interested in careers that require analytical thinking and solving complex problems, such as scientific research or computer programming.",
        "I am drawn to careers that allow me to utilize my imagination and creativity, such as graphic design or writing.",
        "I naturally empathize with others and thrive in collaborative settings, such as counseling or social work.",
        "I am motivated by opportunities for networking, sales, or entrepreneurship.",
        "I am inclined towards careers that involve administrative tasks, financial analysis, or working with numbers."
    ]

    scale = ["1 - Strongly Disagree", "2 - Disagree", "3 - Neutral", "4 - Agree", "5 - Strongly Agree"]

    additional_questions = {
        'R': [
            "I wish to work in a practical and physical environment.",
            "I am someone who prefers outdoor activities and physical work rather than sitting behind a desk.",
            "I like fixing and repairing things."
        ],
        'I': [
            "I am someone who is skilled at analyzing data and interpreting patterns or trends.",
            "I enjoy analyzing data and solving complex problems.",
            "I wish to work in a field where I can conduct research and analyze data."
        ],
        'A': [
            "I enjoy bringing beauty and aesthetic value to the world around me",
            "I am someone who appreciates beauty and aesthetics in various forms, such as music, design, or fashion.",
            "I enjoy attending cultural events and exhibitions."
        ],
        'S': [
            "I am good at understanding and empathising with others.",
            "I am interested in social issues and making a difference in a society",
            "I enjoy organizing and participating in group activities which allows me to make new friends"
        ],
        'E': [
            "I enjoy taking on leadership roles and influencing others.",
            "I am interested in starting my own business or managing a team to achieve goals.",
            "I am good at networking and convincing others of my ideas"
        ],
        'C': [
            "I wish to work in a role that requires precision and accuracy",
            "I am skilled at working with technology and enjoy utilizing software and tools",
            "I am interested in administrative tasks and processes."
        ]
    }

    for i, question in enumerate(questions):
        print(f"Question {i + 1}: {question}\n")
        for j, option in enumerate(scale):
            print(f"{option}")
        response = int(input("\nYour answer: "))
        while response < 1 or response > 5:
            print("Please enter a valid response (1-5).")
            response = int(input("Your answer: "))
        print("--------------------------------------------------")

        dimension = i % 24
        if dimension == 0:
            scores['R'] += response
        elif dimension == 1:
            scores['I'] += response
        elif dimension == 2:
            scores['A'] += response
        elif dimension == 3:
            scores['S'] += response
        elif dimension == 4:
            scores['E'] += response
        elif dimension == 5:
            scores['C'] += response
        elif dimension == 6:
            scores['R'] += response
        elif dimension == 7:
            scores['I'] += response
        elif dimension == 8:
            scores['A'] += response
        elif dimension == 9:
            scores['S'] += response
        elif dimension == 10:
            scores['E'] += response
        elif dimension == 11:
            scores['C'] += response
        elif dimension == 12:
            scores['R'] += response
        elif dimension == 13:
            scores['I'] += response
        elif dimension == 14:
            scores['A'] += response
        elif dimension == 15:
            scores['S'] += response
        elif dimension == 16:
            scores['E'] += response
        elif dimension == 17:
            scores['C'] += response
        elif dimension == 18:
            scores['R'] += response
        elif dimension == 19:
            scores['I'] += response
        elif dimension == 20:
            scores['A'] += response
        elif dimension == 21:
            scores['S'] += response
        elif dimension == 22:
            scores['E'] += response
        elif dimension == 23:
            scores['C'] += response

    print("--------------------------------------------------")
    print("Results:")
    print("--------------------------------------------------")
    
    sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)

    print("Scores for each interest type:")
    for dimension, score in sorted_scores:
        print(f"{dimension}: {score}")
        

    highest_score = sorted_scores[0][1]  # Get the highest score value

    top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
    
    # 4 highest - 555511 - 4 choose 3
    if len(top_scores) == 4:
               
        highest4_1 = sorted_scores[0][0]
        highest4_2 = sorted_scores[1][0]
        highest4_3 = sorted_scores[2][0]
        highest4_4 = sorted_scores[3][0]
        
        print("--------------------------------------------------")
        print("There are multiple interest types with the same highest score.")
        print("Please choose the \033[1mthree options\033[0m that describe you the most (eg.134, without space).")
        print("--------------------------------------------------")

        for i, (dimension, score) in enumerate(top_scores):
            additional_question = random.choice(additional_questions[dimension])
            print(f"{i+1}. {additional_question}")
        
        valid_res = ['1', '2', '3', '4']
        user_res = input("Your answer: ")

        while True:
            user_res = [char for char in user_res if char in valid_res]

            if len(user_res) == 3 and len(set(user_res)) == 3:
                break

            print("   Invalid input. Please try again.")
            user_res = input("Your answer: ")
        
        for x in user_res:
            if x == '1':
                scores[highest4_1] += 1
            if x == '2':
                scores[highest4_2] += 1
            if x == '3':
                scores[highest4_3] += 1
            if x == '4':
                scores[highest4_4] += 1
                
                
        sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        highest_score = sorted_scores[0][1]
        top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
    
    # 5 highest - 555551 - 5 choose 3
    elif len(top_scores) == 5:
               
        highest5_1 = sorted_scores[0][0]
        highest5_2 = sorted_scores[1][0]
        highest5_3 = sorted_scores[2][0]
        highest5_4 = sorted_scores[3][0]
        highest5_5 = sorted_scores[4][0]
        
        print("--------------------------------------------------")
        print("There are multiple interest types with the same highest score.")
        print("Please choose the \033[1mthree options\033[0m that describe you the most (eg.134, without space).")
        print("--------------------------------------------------")

        for i, (dimension, score) in enumerate(top_scores):
            additional_question = random.choice(additional_questions[dimension])
            print(f"{i+1}. {additional_question}")
            
        valid_res = ['1', '2', '3', '4', '5']
        user_res = input("Your answer: ")

        while True:
            user_res = [char for char in user_res if char in valid_res]

            if len(user_res) == 3 and len(set(user_res)) == 3:
                break

            print("   Invalid input. Please try again.")
            user_res = input("Your answer: ")
        
        for x in user_res:
            if x == '1':
                scores[highest5_1] += 1
            if x == '2':
                 scores[highest5_2] += 1
            if x == '3':
                scores[highest5_3] += 1
            if x == '4':
                scores[highest5_4] += 1
            if x == '5':
                scores[highest5_5] += 1
                
        sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        highest_score = sorted_scores[0][1]
        top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
    
    elif len(top_scores) == 6:
               
        highest6_1 = sorted_scores[0][0]
        highest6_2 = sorted_scores[1][0]
        highest6_3 = sorted_scores[2][0]
        highest6_4 = sorted_scores[3][0]
        highest6_5 = sorted_scores[4][0]
        highest6_6 = sorted_scores[5][0]
        
        print("--------------------------------------------------")
        print("There are multiple interest types with the same highest score.")
        print("Please choose the \033[1mthree options\033[0m that describe you the most (eg.134, without space).")
        print("--------------------------------------------------")

        for i, (dimension, score) in enumerate(top_scores):
            additional_question = random.choice(additional_questions[dimension])
            print(f"{i+1}. {additional_question}")
            
        valid_res = ['1', '2', '3', '4', '5', '6']
        user_res = input("Your answer: ")

        while True:
            user_res = [char for char in user_res if char in valid_res]

            if len(user_res) == 3 and len(set(user_res)) == 3:
                break

            print("   Invalid input. Please try again.")
            user_res = input("Your answer: ")
        
        for x in user_res:
            if x == '1':
                scores[highest6_1] += 1
            if x == '2':
                 scores[highest6_2] += 1
            if x == '3':
                scores[highest6_3] += 1
            if x == '4':
                scores[highest6_4] += 1
            if x == '5':
                scores[highest6_5] += 1
            if x == '6':
                scores[highest6_6] += 1
                
        sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
        highest_score = sorted_scores[0][1]
        top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
    
    # two highest - 551111
    elif len(top_scores) == 2:
        
        second_high = sorted_scores[2][1]
        top2_scores = [(dimension, score) for dimension, score in sorted_scores if score == second_high]
        
        # 1 second highest - 554111
        if len(top2_scores) == 1:
            
            second1_1 = sorted_scores[1][0]
            scores[second1_1] += 1
        
        else:
            print("--------------------------------------------------")
            print("There are multiple interest types with the same second-highest score.")
            print("Please choose \033[1mone option\033[0m that describes you the most(eg.3).")
            print("--------------------------------------------------")
        
        # 2 second highest - 554411 - 2 choose 1
        if len(top2_scores) == 2:
            
            second2_1 = sorted_scores[2][0]
            second2_2 = sorted_scores[3][0]
    
            for i, (dimension, score) in enumerate(top2_scores):
                additional_question = random.choice(additional_questions[dimension])
                print(f"{i+1}. {additional_question}")
            
            valid_res = ['1', '2']
            user_res = input("Your answer: ")

            while True:
                user_res = [char for char in user_res if char in valid_res]

                if len(user_res) == 1 and len(set(user_res)) == 1:
                    break

                print("   Invalid input. Please try again.")
                user_res = input("Your answer: ")
        
            for x in user_res:
                if x == '1':
                    scores[second2_1] += 1
                if x == '2':
                    scores[second2_2] += 1
                
            sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
            highest_score = sorted_scores[0][1]
            top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
        
        # 3 second highest - 554441 - 3 choose 1
        elif len(top2_scores) == 3:
            
            second3_1 = sorted_scores[2][0]
            second3_2 = sorted_scores[3][0]
            second3_3 = sorted_scores[4][0]
    
            for i, (dimension, score) in enumerate(top2_scores):
                additional_question = random.choice(additional_questions[dimension])
                print(f"{i+1}. {additional_question}")
            
            valid_res = ['1', '2', '3']
            user_res = input("Your answer: ")

            while True:
                user_res = [char for char in user_res if char in valid_res]

                if len(user_res) == 1 and len(set(user_res)) == 1:
                    break

                print("   Invalid input. Please try again.")
                user_res = input("Your answer: ")
        
            for x in user_res:
                if x == '1':
                    scores[second3_1] += 1
                if x == '2':
                    scores[second3_2] += 1
                if x == '3':
                    scores[second3_3] += 1
                
            sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
            highest_score = sorted_scores[0][1]
            top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
        
        # 4 second highest - 554444 - 4 choose 1
        elif len(top2_scores) == 4:
            
            second4_1 = sorted_scores[2][0]
            second4_2 = sorted_scores[3][0]
            second4_3 = sorted_scores[4][0]
            second4_4 = sorted_scores[4][0]
    
            for i, (dimension, score) in enumerate(top2_scores):
                additional_question = random.choice(additional_questions[dimension])
                print(f"{i+1}. {additional_question}")
            
            valid_res = ['1', '2', '3', '4']
            user_res = input("Your answer: ")

            while True:
                user_res = [char for char in user_res if char in valid_res]

                if len(user_res) == 1 and len(set(user_res)) == 1:
                    break

                print("   Invalid input. Please try again.")
                user_res = input("Your answer: ")
        
            for x in user_res:
                if x == '1':
                    scores[second4_1] += 1
                if x == '2':
                    scores[second4_2] += 1
                if x == '3':
                    scores[second4_3] += 1
                if x == '4':
                    scores[second4_4] += 1
                
            sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
            highest_score = sorted_scores[0][1]
            top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
    
    # 1 highest - 511111
    elif len(top_scores) == 1: 
            
        second_high = sorted_scores[1][1]
        top2_scores = [(dimension, score) for dimension, score in sorted_scores if score == second_high]
        
        # 1 second highest - 541111
        if len(top2_scores) == 1:
            
            third_high = sorted_scores[2][1]
            top3_scores = [(dimension, score) for dimension, score in sorted_scores if score == third_high]
            
            # 1 third highest - 543111
            if len(top3_scores) == 1:
            
                third1_1 = sorted_scores[2][0]
                scores[third1_1] += 1
        
            else:
                print("--------------------------------------------------")
                print("There are multiple interest types with the same third-highest score.")
                print("Please choose \033[1mone option\033[0m that describes you the most(eg.3).")
                print("--------------------------------------------------")

            # 2 third highest - 543311 - 2 choose 1
            if len(top3_scores) == 2:
            
                third2_1 = sorted_scores[2][0]
                third2_2 = sorted_scores[3][0]
    
                for i, (dimension, score) in enumerate(top3_scores):
                    additional_question = random.choice(additional_questions[dimension])
                    print(f"{i+1}. {additional_question}")
            
                valid_res = ['1', '2']
                user_res = input("Your answer: ")

                while True:
                    user_res = [char for char in user_res if char in valid_res]

                    if len(user_res) == 1 and len(set(user_res)) == 1:
                        break

                    print("   Invalid input. Please try again.")
                    user_res = input("Your answer: ")
        
                for x in user_res:
                    if x == '1':
                        scores[third2_1] += 1
                    if x == '2':
                        scores[third2_2] += 1
                
                sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
                highest_score = sorted_scores[0][1]
                top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
                
            # 3 third highest - 543331 - 3 choose 1
            if len(top3_scores) == 3:
            
                third3_1 = sorted_scores[2][0]
                third3_2 = sorted_scores[3][0]
                third3_3 = sorted_scores[4][0]
    
                for i, (dimension, score) in enumerate(top3_scores):
                    additional_question = random.choice(additional_questions[dimension])
                    print(f"{i+1}. {additional_question}")
            
                valid_res = ['1', '2', '3']
                user_res = input("Your answer: ")

                while True:
                    user_res = [char for char in user_res if char in valid_res]

                    if len(user_res) == 1 and len(set(user_res)) == 1:
                        break

                    print("   Invalid input. Please try again.")
                    user_res = input("Your answer: ")
        
                for x in user_res:
                    if x == '1':
                        scores[third3_1] += 1
                    if x == '2':
                        scores[third3_2] += 1
                    if x == '3':
                        scores[third3_3] += 1
                
                sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
                highest_score = sorted_scores[0][1]
                top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
                
            # 4 third highest - 543333 - 4 choose 1
            if len(top3_scores) == 4:
            
                third4_1 = sorted_scores[2][0]
                third4_2 = sorted_scores[3][0]
                third4_3 = sorted_scores[4][0]
                third4_4 = sorted_scores[5][0]
    
                for i, (dimension, score) in enumerate(top3_scores):
                    additional_question = random.choice(additional_questions[dimension])
                    print(f"{i+1}. {additional_question}")
            
                valid_res = ['1', '2', '3', '4']
                user_res = input("Your answer: ")

                while True:
                    user_res = [char for char in user_res if char in valid_res]

                    if len(user_res) == 1 and len(set(user_res)) == 1:
                        break

                    print("   Invalid input. Please try again.")
                    user_res = input("Your answer: ")
        
                for x in user_res:
                    if x == '1':
                        scores[third4_1] += 1
                    if x == '2':
                        scores[third4_2] += 1
                    if x == '3':
                        scores[third4_3] += 1
                    if x == '4':
                        scores[third4_4] += 1
                
                sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
                highest_score = sorted_scores[0][1]
                top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
        
        # more than 1 second highest - 544111
        if len(top2_scores) > 1:
            
            second_high = sorted_scores[1][1]
            top2_scores = [(dimension, score) for dimension, score in sorted_scores if score == second_high]
            
            # 2 second highest - 544111
            if len(top2_scores) == 2:
            
                second2_1 = sorted_scores[1][0]
                second2_2 = sorted_scores[2][0]
                scores[second2_1] += 1
                scores[second2_2] += 1
        
            else:
                print("--------------------------------------------------")
                print("There are multiple interest types with the same second-highest score.")
                print("Please choose \033[1mtwo options\033[0m that describe you the most(eg.12, without space).")
                print("--------------------------------------------------")
            
            # 3 second highest - 544411 - 3 choose 2
            if len(top2_scores) == 3:
            
                second3_1 = sorted_scores[1][0]
                second3_2 = sorted_scores[2][0]
                second3_3 = sorted_scores[3][0]                
    
                for i, (dimension, score) in enumerate(top2_scores):
                    additional_question = random.choice(additional_questions[dimension])
                    print(f"{i+1}. {additional_question}")
            
                valid_res = ['1', '2', '3']
                user_res = input("Your answer: ")

                while True:
                    user_res = [char for char in user_res if char in valid_res]

                    if len(user_res) == 2 and len(set(user_res)) == 2:
                        break

                    print("   Invalid input. Please try again.")
                    user_res = input("Your answer: ")
        
                for x in user_res:
                    if x == '1':
                        scores[second3_1] += 1
                    if x == '2':
                        scores[second3_2] += 1
                    if x == '3':
                        scores[second3_3] += 1
                
                sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
                highest_score = sorted_scores[0][1]
                top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
                
            # 4 second highest - 544441 - 4 choose 2
            if len(top2_scores) == 4:
            
                second4_1 = sorted_scores[1][0]
                second4_2 = sorted_scores[2][0]
                second4_3 = sorted_scores[3][0]
                second4_4 = sorted_scores[4][0]
    
                for i, (dimension, score) in enumerate(top2_scores):
                    additional_question = random.choice(additional_questions[dimension])
                    print(f"{i+1}. {additional_question}")
            
                valid_res = ['1', '2', '3', '4']
                user_res = input("Your answer: ")

                while True:
                    user_res = [char for char in user_res if char in valid_res]

                    if len(user_res) == 2 and len(set(user_res)) == 2:
                        break

                    print("   Invalid input. Please try again.")
                    user_res = input("Your answer: ")
        
                for x in user_res:
                    if x == '1':
                        scores[second4_1] += 1
                    if x == '2':
                        scores[second4_2] += 1
                    if x == '3':
                        scores[second4_3] += 1
                    if x == '4':
                        scores[second4_4] += 1
                
                sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
                highest_score = sorted_scores[0][1]
                top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
                
            # 5 second highest - 544444 - 5 choose 2
            if len(top2_scores) == 5:
            
                second5_1 = sorted_scores[1][0]
                second5_2 = sorted_scores[2][0]
                second5_3 = sorted_scores[3][0]
                second5_4 = sorted_scores[4][0]
                second5_5 = sorted_scores[5][0]
    
                for i, (dimension, score) in enumerate(top2_scores):
                    additional_question = random.choice(additional_questions[dimension])
                    print(f"{i+1}. {additional_question}")
            
                valid_res = ['1', '2', '3', '4', '5']
                user_res = input("Your answer: ")

                while True:
                    user_res = [char for char in user_res if char in valid_res]

                    if len(user_res) == 2 and len(set(user_res)) == 2:
                        break

                    print("   Invalid input. Please try again.")
                    user_res = input("Your answer: ")
        
                for x in user_res:
                    if x == '1':
                        scores[second5_1] += 1
                    if x == '2':
                        scores[second5_2] += 1
                    if x == '3':
                        scores[second5_3] += 1
                    if x == '4':
                        scores[second5_4] += 1
                    if x == '5':
                        scores[second5_5] += 1
                
                sorted_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)
                highest_score = sorted_scores[0][1]
                top_scores = [(dimension, score) for dimension, score in sorted_scores if score == highest_score]
 
        
    top_scores = sorted(scores.items(), key=lambda x: x[1], reverse=True)[:3]
    
    print("--------------------------------------------------")
    print("Your highest interest types are:")
    print(" ")
    for dimension, score in top_scores:
        if dimension == 'R':
            print("\033[1mRealistic\033[0m: You are often good at mechanical or athletic jobs")
        elif dimension == 'I':
            print("\033[1mInvestigative\033[0m: You like to watch, learn, analyze and solve problems")
        elif dimension == 'A':
            print("\033[1mArtistic\033[0m: You like to work in unstructured situations where they can use their creativity")
        elif dimension == 'S':
            print("\033[1mSocial\033[0m: You like to work with other people, rather than things")
        elif dimension == 'E':
            print("\033[1mEnterprising\033[0m: You like to work with others and enjoy persuading and and performing")
        elif dimension == 'C':
            print("\033[1mConventional\033[0m: You are very detail oriented,organized and like to work with data")
            
    
    riasec_courses = {
    'RIA': [('Mathematics and Applied Mathematics', '-- You will explore topics such as calculus, algebra, statistics, and mathematical modeling* You will learn to analyze complex data, develop mathematical models to solve real-world problems')
            , ('Science in Physics', '-- You will study into topics such as classical mechanics, quantum mechanics, and electromagnetism* This course will provide you with a solid foundation in scientific research, experimental design, and data analysis.')
            , ('Marine Environmental Chemistry', '-- You will explore the chemistry of marine ecosystems, studying topics such as water quality on marine environments* You will analyze chemical processes, and develop strategies for marine conservation and sustainability')
            , ('Science in Marine Biotechnology', '-- You will equip the necessary knowledge and skills to manage the capitalization of aquatic resources* You will be trained to be conscious of current environmental issues and marine biotechnology problems.') ],
    'RIS': [('Cyber Security','-- You will combine technical knowledge and understandings of human behaviour to protect digital systems from cyber threats* In this course, you will learn about network security, data encryption and threat detection')
            , ('Digital Media Technology','-- You study topics including graphic design, multimedia production and user experience (UX) design* From this course, you will enhance your technical expertise and creative skills to design compelling digital experiences')
            , ('International Business','-- You will gain knowledge in areas such as international trade, global marketing, and strategic planning* This course involves analyzing and managing business activities and developing strategies to expand businesses globally')
            , ('New Energy Science and Engineering','-- You will study energy technologies that aim to address environmental concerns* It focuses on the development and implementation of sustainable and renewable energy sources to promote a sustainable future')],
    'RIE': [('Data Science','-- You will need to apply statistical analysis and programming skills to predict trends and discover valuable insights* This course needs to analyse large datasets, uncover patterns and make data-driven decisions')
            ,('Computer Science and Technology','-- You will learn problem-solving skills and programming knowledge to create efficient algorithms and build applications* It needs to explore emerging technologies and develop innovative computer systems')
            ,('Chemical Engineering','--You will apply scientific principles and engineering concepts to the transform raw materials into useful products* You will study pharmaceuticals, energy production, materials science, environmental sustainability')],
    'RIC': [('Software Engineering','-- You will need to create innovative solutions, write code, and ensure the performance of software programs* You also need to design, develop, and maintain software systems and applications.')
            ,('Electrical and Electronic Engineering','-- You will need to create innovative solutions, design circuits and electronic systems* You also need to develop and maintain electronic devices and communication networks.')
            ,('Artificial Intelligence','-- You will work on creating machine learning models, expert systems and computer vision algorithms* You also need to develop intelligent systems, NLP systems, and technologies that mimic human behaviour.' )],
    'RAS': [('English Language and Literature','-- You can develop a deep understanding of the English language, its historical context and literature* This course provides you with a comprehensive knowledge of critical thinking and effective communication skills.')
            ,('Chinese Studies','-- You will gain a comprehensive understanding of the Chinese language, history, culture, and its society* It will provide you the opportunity to explore various aspects of China, including its literature, philosophy and traditions.')
            ,('Science in Marine Biotechnology','-- You will be equipped with the knowledge and skills to manage the capitalization of aquatic resources* You will be trained to be conscious of current environmental issues and marine biotechnology problems.')],
    'RAE': [('Advertising','-- You can gain a comprehensive understanding of advertising principles, consumer behavior, market trends and strategies* This course develops practical skills in creative design, brand management and media planning')
            ,('Journalism','-- You develop a comprehensive understanding of news reporting, investigative journalism and storytelling techniques* This course enhances practical skills in interviewing, research, writing, multimedia production and media law.')
            ,('Fashion design','-- You will understand the fashion history, design principles, garment construction, textile selection and fashion business* This course develops practical skills in sketching, pattern-making and fashion illustration.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Tunku Abdul Rahman University of Management and Technology (Fashion Design),* https://www.tarc.edu.my/fcci/programmes/bachelor-degree/bachelor-of-design-honours-in-fashion-design/ ')],  
    'RAC': [('Traditional Chinese Medicine','-- You can understand TCM principles, diagnostic techniques, herbal medicine formulations* This course develops practical skills for pulse diagnosis, herbal medicine compounding, and treatment planning.')
            ,('Industrial Design','-- You will learn design principles, 3D modeling, prototyping, and user-centered design* This course develops practical skills in sketching, computer-aided design (CAD), rendering, and design thinking methodologies.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Limkokwing University of Creative Technology (Industrial Design),* https://www.limkokwing.net/malaysia/academic/courses_details/bachelor-of-arts-hons-in-industrial-design')
            ,('Fashion Design','-- You will understand the fashion history, design principles, garment construction, textile selection and fashion business* This course develops practical skills in sketching, pattern-making and fashion illustration.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Tunku Abdul Rahman University of Management and Technology (Fashion Design),* https://www.tarc.edu.my/fcci/programmes/bachelor-degree/bachelor-of-design-honours-in-fashion-design/ ')],
    'RSE': [('Journalism','-- You develop a comprehensive understanding of news reporting, investigative journalism and storytelling techniques* This course enhances practical skills in interviewing, research, writing, multimedia production and media law.')
            ,('Environmental Science','-- You learn about environmental issues, conservation principles, pollution control and sustainability practices* It builds practical skills in data analysis, environmental monitoring and environmental impact assessment.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* University of Nottingham Malaysia (Environmental Science),* https://www.nottingham.edu.my/ugstudy/course/environmental-science-bsc-hons ')
            ,('International Business','-- You will gain knowledge in areas such as international trade, global marketing, and strategic planning* This course involves analyzing and managing business activities and developing strategies to expand businesses globally')],
    'RSC': [('Traditional Chinese Medicine','-- You will understand TCM principles, diagnostic techniques, herbal medicine formulations* This course develops practical skills for pulse diagnosis, herbal medicine compounding, and treatment planning.')
            ,('Nursing','-- You can gain a comprehensive understanding of anatomy, physiology, pharmacology, patient assessment and nursing practices* It develops practical skills for clinical procedures, patient communication, critical thinking, and evidence-based practice.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* International Medical University Malaysia (Nursing), * https://www.imu.edu.my/academics/undergraduate/nursing/ ')
            ,('Pharmacy','-- You will study about pharmaceutical sciences, pharmacology, drug interactions and patient counselling* It equips you with the skill medication management, compounding, drug information research, and patient care.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Monash University Malaysia (Pharmacy), * https://www.monash.edu.my/study/undergraduate/pharmacy/bachelor-pharmacy ')],
    'REC': [('Data Science','-- You will need to apply statistical analysis and programming skills to predict trends and discover valuable insights* This course needs to analyse large datasets, uncover patterns and make data-driven decisions')
            ,('Civil Engineering','-- You will learn about structural analysis, construction materials and geotechnical engineering* It develops practical skills in designing structures, utilizing computer-aided design (CAD) software.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Monash University Malaysia (Civil Engineering), * https://www.monash.edu.my/study/undergraduate/engineering/bachelor-of-engineering-honours-in-civil-engineering ')
            ,('Accounting','-- You will understand concepts of financial accounting, managerial accounting, taxation and financial analysis* It enhances practical skills in areas such as cost analysis, and utilizing accounting software')],
    'IAS': [('Journalism','-- You develop a comprehensive understanding of news reporting, investigative journalism, and storytelling techniques* This course enhances practical skills in interviewing, research, writing, multimedia production and media law.')
            ,('Chinese Studies','-- You will gain a comprehensive understanding of the Chinese language, history, culture and its society* It will provide you the opportunity to explore various aspects of China, including its literature, philosophy and traditions.')
            ,('Music and Performing Arts','-- You will explore different genres and styles, develop your technical skills and artistic expression* In this course, you will study music theory, instruments and refine your vocal abilities.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* UCSI University (Music and Performing Arts),* https://www.ucsiuniversity.edu.my/programmes/bachelor-contemporary-music-hons ')],
    'IAE': [('Advertising','-- You can gain a comprehensive understanding of advertising principles, consumer behavior, market trends and campaign strategies* This course develops practical skills in creative design, brand management and media planning')
            ,('Journalism','-- You develop a comprehensive understanding of news reporting, investigative journalism, and storytelling techniques* This course enhances practical skills in interviewing, research, writing, multimedia production and media law.')
            ,('Fashion design','-- You will understand the fashion history, design principles, garment construction, textile selection and fashion business* This course develops practical skills in sketching, pattern-making and fashion illustration.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Tunku Abdul Rahman University of Management and Technology (Fashion Design),* https://www.tarc.edu.my/fcci/programmes/bachelor-degree/bachelor-of-design-honours-in-fashion-design/ ')], 
    'IAC': [('Digital Media Technology','-- You study topics including graphic design, multimedia production and user experience (UX) design* From this course, you will enhance your technical expertise and creative skills to design compelling digital experiences')
            ,('Architecture','-- You will learn to develop architectural models, engage in studio-based projects, collaborate with industry professionals* You will understand architectural principles and sustainable design practices* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Sunway University (Architecture),* https://university.sunway.edu.my/soa/ba-interior-architecture ')
            ,('Design in Creative Media','-- You will understand design principles, visual communication and user experience design* This course works on real-world projects, collaborate with peers, and build a portfolio that showcases your creative abilities* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Taylor’s University (Design in Creative Media),* https://university.taylors.edu.my/en/study/undergraduate/design/bachelor-of-design-hons-creative-media.html ')],
    'ISE': [('International Business','-- You will gain knowledge in areas such as international trade, global marketing, and strategic planning* This course involves analyzing and managing business activities and developing strategies to expand businesses globally')
            ,('Business Administration','-- You learn about marketing, finance, human resources, operations, and strategic management in this course* Additionally, you will enhance skills for business analyst, marketing manager, entrepreneur or business consultant* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* University Tunku Abdul Rahman (Business Administration),* https://study.utar.edu.my/business-administration.php ')
            ,('International Relations','-- This course will provide you with knowledge about political systems, international law and global conflicts* You will develop critical thinking skills and understanding the complexities of international affairs* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Taylor’s University (International Relations),* https://university.taylors.edu.my/en/study/undergraduate/liberal-arts-and-sciences/bachelor-of-social-science-international-relations.html ')],
    'ISC': [('Traditional Chinese Medicine','-- You can understand TCM principles, diagnostic techniques, herbal medicine formulations* This course develops practical skills for pulse diagnosis, herbal medicine compounding, and treatment planning.')
            ,('Library and Information Science','-- You will learn about techniques in information technology, digital libraries and uses of information* This course explores the roles of librarian, information specialist, archivist and digital content manager* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* University Teknologi MARA (Library and Information Science ),* https://kppim.uitm.edu.my/programme')
            ,('Information Technology','-- You will study about programming, database management, network administration and cybersecurity* You will be equipped with the skills in the IT industry, such as software developer, systems analyst and IT consultant* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Taylor’s University (Information Technology),* https://university.taylors.edu.my/en/study/undergraduate/computing/bachelor-information-technology-hons.html?gclid=Cj0KCQjwy9-kBhCHARIsAHpBjHirvPCHiVo-6N2qbS_Xx8R41IUn5if-PVNxQPR7Q5Bu1bR_kItLn4IaAp3GEALw_wcB&utm_source=Google&utm_medium=cpl&utm_campaign=2023_C3_TU_SEM_LeadGen_Courses_SchoolOfCompIT&utm_term=Google&utm_content=TU_school_of_computing_it&ef_id=Cj0KCQjwy9-kBhCHARIsAHpBjHirvPCHiVo-6N2qbS_Xx8R41IUn5if-PVNxQPR7Q5Bu1bR_kItLn4IaAp3GEALw_wcB%3AG%3As&s_kwcid=AL%21995%213%21627499960227%21b%21%21g%21%21information+technology+degree&gclsrc=aw.ds&kw=information+technology+degree&match=b&serp=&gad=1')],
    'IEC': [('Actuarial Science','-- You will gain a strong foundation in statistical concepts, risk assessment and management and financial modeling* This course will equip you with the essential skills and knowledge required for a career as an actuarial professional.* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Sunway University (Actuarial Science),* https://university.sunway.edu.my/sms/bsc-actuarial')
            ,('Finance','-- You will gain a comprehensive understanding of financial concepts, tools, and techniques in finance-related career paths* You will explore roles such as financial analyst, investment manager, risk analyst, financial planner or corporate treasurer')
            ,('Accounting','-- You will understand concepts of financial accounting, managerial accounting, taxation, auditing, and financial analysis* It enhances practical skills in areas such as cost analysis, and utilizing accounting software')],
    'ASE': [('Advertising','-- You can gain a comprehensive understanding of advertising principles, consumer behavior, market trends and campaign strategies* This course develops practical skills in creative design, brand management and media planning')
            ,('Education','-- You will gain a deep understanding of educational theories, teaching methodologies, and strategies for student engagement* You will specialize in specific educational levels such as early childhood education and secondary education* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* HELP University (Education),* https://university.help.edu.my/course/bachelor-of-education-tesl/')
            ,('International Relations','-- This course will provide you with knowledge about political systems, international law and global conflicts* You will develop critical thinking skills and understanding the complexities of international affairs* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Taylor’s University (International Relations),* https://university.taylors.edu.my/en/study/undergraduate/liberal-arts-and-sciences/bachelor-of-social-science-international-relations.html ')],
    'ASC': [('Journalism','-- You develop a comprehensive understanding of news reporting, investigative journalism, and storytelling techniques* This course enhances practical skills in interviewing, research, writing, multimedia production and media law.')
            ,('Early Childhood Education','-- You will understand child development, educational theories, and best practices in early childhood education* You may work in various early childhood settings, such as preschools, daycare centres and kindergartens* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* University Tunku Abdul Rahman (Early Childhood Education),* https://study.utar.edu.my/early-childhood-education.php ')
            ,('Education','-- You will gain a deep understanding of educational theories, teaching methodologies, and strategies for student engagement* You will specialize in specific educational levels such as early childhood education and secondary education* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* HELP University (Education),* https://university.help.edu.my/course/bachelor-of-education-tesl/')],   
    'AEC': [('Advertising','-- You can gain a comprehensive understanding of advertising principles, consumer behavior, market trends and campaign strategies* This course develops practical skills in creative design, brand management and media planning')
            ,('Mass Communication','-- You will study communication theories, media practices, and techniques for effective message dissemination* You will explore roles such as journalist, public relations specialist, advertising executive and media producer* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Taylor’s University (Mass Communication),* https://university.taylors.edu.my/en/study/undergraduate/communication/bachelor-of-mass-communication-hons.html?gclid=Cj0KCQjwy9-kBhCHARIsAHpBjHiQb0Fc04t7YmV52XaWXSgxDj-0rxXr8dLaKIrDYxn9HlCpuPSDZfwaAlohEALw_wcB&utm_source=Google&utm_medium=cpl&utm_campaign=2023_C3_TU_SEM_LeadGen_Courses_SchoolOfMediaComm&utm_term=Google&utm_content=TU_school_of_media_communication&ef_id=Cj0KCQjwy9-kBhCHARIsAHpBjHiQb0Fc04t7YmV52XaWXSgxDj-0rxXr8dLaKIrDYxn9HlCpuPSDZfwaAlohEALw_wcB%3AG%3As&s_kwcid=AL%21995%213%21592316156289%21b%21%21g%21%21taylor+mass+communication&gclsrc=aw.ds&ds_rl=1297255&kw=taylor+mass+communication&match=b&serp=&gad=1 ')
            ,('Interior Design','-- You will understand design principles, spatial planning, and skills for creating functional interior spaces* You may work as an interior designer, design consultant, space planner, or design* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Taylor’s University (Interior Architecture),* https://university.taylors.edu.my/en/study/undergraduate/architecture/bachelor-of-arts-hons-interior-architecture.html?ef_id=Cj0KCQjwy9-kBhCHARIsAHpBjHi7rsj5Q9J6MW-2I1uF-iquORpoLCTtHmBYr2QWBTaoglcwjrkBdNAaAmqzEALw_wcB%3AG%3As&s_kwcid=AL%21995%213%21657659738058%21%21%21g%21%21&gclsrc=aw.ds&utm_source=Google&gad=1&utm_medium=cpl&utm_campaign=2023_C3_TU_SEM_LeadGen_Courses_DesignSchool&utm_term=Google&utm_content=TU_design_school&gclid=Cj0KCQjwy9-kBhCHARIsAHpBjHi7rsj5Q9J6MW-2I1uF-iquORpoLCTtHmBYr2QWBTaoglcwjrkBdNAaAmqzEALw_wcB&gclsrc=aw.ds')],
    'SEC': [('Hospitality Management','-- You will learn hospitality industry, customer service principles, and managerial skills in this field* You may work in various hospitality sectors such as hotels, resorts, restaurants, event venues, or tourism organizations* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* SEGi University (Hospitality Management),* https://university.segi.edu.my/?course=bachelor-of-hospitality-management-hons')
            ,('Public Relations','-- You will gain a comprehensive understanding of communication principles, media relations, and strategic planning* You will have the skills to work in PR agencies, corporate communication departments and government institutions* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* University Tunku Abdul Rahman (Public Relations),* https://study.utar.edu.my/public-relations.php ')
            ,('Mass Communication','-- You will study communication theories, media practices, and techniques for effective message dissemination* You will explore roles such as journalist, public relations specialist, advertising executive and media producer* This programme is \033[38;5;202munavailable in XMUM\033[0m, here is a recommendation for you from:* Taylor’s University (Mass Communication),* https://university.taylors.edu.my/en/study/undergraduate/communication/bachelor-of-mass-communication-hons.html?gclid=Cj0KCQjwy9-kBhCHARIsAHpBjHiQb0Fc04t7YmV52XaWXSgxDj-0rxXr8dLaKIrDYxn9HlCpuPSDZfwaAlohEALw_wcB&utm_source=Google&utm_medium=cpl&utm_campaign=2023_C3_TU_SEM_LeadGen_Courses_SchoolOfMediaComm&utm_term=Google&utm_content=TU_school_of_media_communication&ef_id=Cj0KCQjwy9-kBhCHARIsAHpBjHiQb0Fc04t7YmV52XaWXSgxDj-0rxXr8dLaKIrDYxn9HlCpuPSDZfwaAlohEALw_wcB%3AG%3As&s_kwcid=AL%21995%213%21592316156289%21b%21%21g%21%21taylor+mass+communication&gclsrc=aw.ds&ds_rl=1297255&kw=taylor+mass+communication&match=b&serp=&gad=1 ')],
    }
    
    print("--------------------------------------------------")
    print("Your recommended courses are:")
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'I', 'A']):
        courses = riasec_courses['RIA']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
        
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'I', 'S']):
        courses = riasec_courses['RIS']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'I', 'E']):
        courses = riasec_courses['RIE']
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'I', 'C']):
        courses = riasec_courses['RIC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'A', 'S']):
        courses = riasec_courses['RAS']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'A', 'E']):
        courses = riasec_courses['RAE']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'A', 'C']):
        courses = riasec_courses['RAC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'S', 'E']):
        courses = riasec_courses['RSE']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'S', 'C']):
        courses = riasec_courses['RSC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['R', 'E', 'C']):
        courses = riasec_courses['REC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['I', 'A', 'S']):
        courses = riasec_courses['IAS']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['I', 'A', 'E']):
        courses = riasec_courses['IAE']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['I', 'A', 'C']):
        courses = riasec_courses['IAC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['I', 'S', 'E']):
        courses = riasec_courses['ISE']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['I', 'S', 'C']):
        courses = riasec_courses['ISC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['I', 'E', 'C']):
        courses = riasec_courses['IEC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['A', 'S', 'E']):
        courses = riasec_courses['ASE']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['A', 'S', 'C']):
        courses = riasec_courses['ASC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['A', 'E', 'C']):
        courses = riasec_courses['AEC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
            
    if all(key in [dimension for dimension, score in top_scores] for key in ['S', 'E', 'C']):
        courses = riasec_courses['SEC']
        i = 1
        for course, description in courses:
            bold_course = "\033[1m" + course + "\033[0m"  # Add bold formatting to the course name
            print(i,bold_course)
            split_description = description.split("*")
            for desc in split_description:
                print(desc)
            print("")
            i = i+1
    print("--------------------------------------------------")
    print("For details about \033[34mprogrammes in XMUM\033[0m, click here\U0001F449 https://www.xmu.edu.my/16268/list.htm")
    print("--------------------------------------------------")
    print("Thank you for using X-counsellor! \u2764\uFE0F")


        
take_riasec_test()
# Out:
# Welcome to X-Counsellor 😀, your trusted companion for guidance in choosing your best courses.✌
# Our goal is to make your journey of selecting courses a smooth and enjoyable experience!
# To assist you in selecting the best courses for your needs, please take a moment to answer a few simple questions.
# ------------------------------------------------------------------------------------------------------------------
# ATTENTION!!! Please answer the questions thoughtfully and honestly to ensure accurate results !!!ATTENTION
# ------------------------------------------------------------------------------------------------------------------
# Please rate the following statements from 1 (strongly disagree) to 5 (strongly agree).
# ------------------------------------------------------------------------------------------------------------------
# Question 1: I enjoy working with my hands and being physically active.
#
# 1 - Strongly Disagree
# 2 - Disagree
# 3 - Neutral
# 4 - Agree
# ...
